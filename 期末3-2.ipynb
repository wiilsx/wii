    "一刻千金": {"解釋": "比喻時間極為珍貴。", "造句": "我們要珍惜一刻千金的青春時光，努力學習。", "挖空": "我們要珍惜＿＿＿＿的青春時光，努力學習。", "典故": "刻，是古記計時的名稱，一晝夜共分一百刻。一刻在今天則大約是十五分鐘，也用來指短暫的時間。「一刻千金」意謂極短暫的時間，卻有著千金的價值，也就表示時間是極為寶貴，教人珍惜的。北宋蘇軾〈春夜〉詩，便有「春宵一刻直千金」之語。直，通「值」。這句詩的意思就是春夜歡樂時光美好可貴，每一個短暫的瞬間都教人覺得值得珍惜。後來「一刻千金」這句成語就從這裡演變而出，用來比喻時間極為珍貴。"},
             }
riddles = {
    "一目了然": {"謎語": "獨眼龍看戲", "解釋": "看一眼就完全清楚明白。", "造句": "這張設計圖畫得十分詳細，即使外行人看了也會一目了然。"},
    "目中無人": {"謎語": "空棺材出喪", "解釋": "眼中除自己外，沒有他人。形容人高傲自大，瞧不起別人。", "造句": "才有那麼一點成就，他竟然就目中無人起來。"},
    "鋌而走險": {"謎語": "孕婦走獨木橋", "解釋": "指在窮途末路或受逼迫時採取冒險行動或不正當的行為。", "造句": "為了償還債務，他竟鋌而走險去搶劫銀樓。"},
    "輕描淡寫": {"謎語": "白開水畫畫", "解釋": "指戲劇中著力不多的描繪或敘述。後用輕描淡寫形容言論或寫作時，避開關鍵，將重點輕輕帶過。", "造句": "對於近況，他在信上只有輕描淡寫的幾句話。"},
    "無法無天": {"謎語": "禿子打傘", "解釋": "沒有法紀、天理。形容人肆意妄為毫無顧忌。", "造句": "這幾個無法無天的流氓作惡多端，已經被警察逮捕，移送法辦了。"},
    }
# 存儲使用者學習的成語
learned_idioms = set()
learned_riddles = set()

def learn_idiom():
    idiom = random.choice(list(idioms.keys()))
    print(f"成語：{idiom}")
    print(f"解釋：{idioms[idiom]['解釋']}")
    print(f"造句：{idioms[idiom]['造句']}")
    learned_idioms.add(idiom)

def idiom_quiz():
    idiom = random.choice(list(idioms.keys()))
    fake_definitions = [idioms[idiom]['解釋']]
    while len(fake_definitions) < 3:
        fake_definition = random.choice(list(idioms.values()))['解釋']
        if fake_definition not in fake_definitions:
            fake_definitions.append(fake_definition)

    random.shuffle(fake_definitions)

    print(f"成語：{idiom}")
    for i, definition in enumerate(fake_definitions):
        print(f"{i + 1}. {definition}")

    answer = int(input("請選擇正確的解釋（輸入編號）："))
    if fake_definitions[answer - 1] == idioms[idiom]['解釋']:
        print("答對了！")
        learned_idioms.add(idiom)
    else:
        print("答錯了。提示ˋ：")
        print(f"造句：{idioms[idiom]['造句']}")

def idiom_fill_in_the_blank():
    idiom = random.choice(list(idioms.keys()))
    print(f"挖空：{idioms[idiom]['挖空']}")
    answer = input("請填入正確的成語：")
    if answer == idiom:
        print("答對了！")
        learned_idioms.add(idiom)
    else:
        print("答錯了。正確答案是：" + idiom)

def idiom_story():
    idiom = input("請輸入要查詢故事的成語：")
    if idiom in idioms:
        print(f"典故：{idioms[idiom]['典故']}")
    else:
        print("找不到該成語的典故。")

def play_riddles():
    selected_riddle = random.choice(list(riddles.keys()))
    print(f"謎語：{riddles[selected_riddle]['謎語']}")
    answer = input("請猜出正確的成語：")

    if answer == selected_riddle:
        print("答對了！")
        learned_riddles.add(answer)
    else:
        print(f"答錯了。正確答案是：{selected_riddle}")
def view_all_idioms():
    print("所有成語列表：")
    for idiom in idioms.keys():
        print(idiom)

def add_idiom():
    new_idiom = input("請輸入新的成語：")
    definition = input("請輸入成語的解釋：")
    example = input("請輸入成語的造句：")
    idioms[new_idiom] = {"解釋": definition, "造句": example}
    print("成語已新增。")

def save_and_exit():
    with open('learned_idioms.json', 'w') as f:
        json.dump(list(learned_idioms), f)
    print("已保存學習記錄，程式即將退出。")

# 主程式
while True:
    print("\n1. 學習成語")
    print("2. 成語選擇題")
    print("3. 成語填空")
    print("4. 成語典故")
    print("5. 歇後語猜謎")
    print("6. 查看全部成語")
    print("7. 新增成語")
    print("8. 保存與退出")

    choice = input("請選擇功能（輸入編號）：")

    if choice == '1':
        learn_idiom()
    elif choice == '2':
        idiom_quiz()
    elif choice == '3':
        idiom_fill_in_the_blank()
    elif choice == '4':
        idiom_story()
    elif choice == '5':
        play_riddles()
    elif choice == '6':
        view_all_idioms()
    elif choice == '7':
        add_idiom()
    elif choice == '8':
        save_and_exit()
        break
    else:
        print("請輸入有效的編號。")
# Out:
# 1. 學習成語
# 2. 成語選擇題
# 3. 成語填空
# 4. 成語典故
# 5. 歇後語猜謎
# 6. 查看全部成語
# 7. 新增成語
# 8. 保存與退出
# 請選擇功能（輸入編號）：1
# 成語：畫蛇添足
# 解釋：畫好蛇後，多事為它添上蛇足，結果反而失去本已贏得的酒。比喻多此一舉，反將事情弄糟。
# 造句：本來一場成功的演講，就敗在結尾那畫蛇添足的笑話。
#
# 1. 學習成語
# 2. 成語選擇題
# 3. 成語填空
# 4. 成語典故
# 5. 歇後語猜謎
# 6. 查看全部成語
# 7. 新增成語
# 8. 保存與退出
# 請選擇功能（輸入編號）：2
# 成語：美輪美奐
# 1. 形容房屋規模高大、裝飾華美。
# 2. 「鳳毛」，鳳凰的羽毛。麟角」，麒麟的角。「鳳毛麟角」比喻稀罕珍貴的人、物。
# 3. 居於荒野，久處寂寞，聽到人的腳步聲就高興。
# 請選擇正確的解釋（輸入編號）：1
# 答對了！
#
# 1. 學習成語
# 2. 成語選擇題
# 3. 成語填空
# 4. 成語典故
# 5. 歇後語猜謎
# 6. 查看全部成語
# 7. 新增成語
# 8. 保存與退出
# 請選擇功能（輸入編號）：3
# 挖空：我都聽不懂他們談論的內容，頗有＿＿＿的感慨。
# 請填入正確的成語：2
# 答錯了。正確答案是：井底之蛙
#
# 1. 學習成語
# 2. 成語選擇題
# 3. 成語填空
# 4. 成語典故
# 5. 歇後語猜謎
# 6. 查看全部成語
# 7. 新增成語
# 8. 保存與退出
# 請選擇功能（輸入編號）：4
# 請輸入要查詢故事的成語：九牛
# 找不到該成語的典故。
#
# 1. 學習成語
# 2. 成語選擇題
# 3. 成語填空
# 4. 成語典故
# 5. 歇後語猜謎
# 6. 查看全部成語
# 7. 新增成語
# 8. 保存與退出
# 請選擇功能（輸入編號）：4
# 請輸入要查詢故事的成語：九牛一毛
# ...
